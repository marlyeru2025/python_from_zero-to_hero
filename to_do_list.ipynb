# %%
print ('welcome')
def to_do_list():
  tasks = []
  while True:
    print("1. add new task")
    print("2. remove task")
    print("3. view task")
    print("4. exit")
    choice = int(input("enter your choice: "))
    if choice == 1:
      task = input("enter new task: ")
      tasks.append(task)

    elif choice == 2:
      task = input("enter task to remove: ")
      if task in tasks:
        tasks.remove(task)
      else:
        print("task not found")

    elif choice ==3:
      print("your tasks are: ")
      for task in tasks:
        print(task)
    elif choice == 4:
      break
    else:
      print("invalid choice")
to_do_list()
print("thank you")
# Out:
# welcome
# 1. add new task
# 2. remove task
# 3. view task
# 4. exit
# enter your choice: 1
# enter new task: study math
# 1. add new task
# 2. remove task
# 3. view task
# 4. exit
# enter your choice: 1
# enter new task: study python
# 1. add new task
# 2. remove task
# 3. view task
# 4. exit
# enter your choice: 3
# your tasks are:
# study math
# study python
# 1. add new task
# 2. remove task
# 3. view task
# 4. exit
# enter your choice: 4
# thank you
